# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\faisa\Downloads\Global_Superstore(CSV).csv", encoding="latin-1")
df.head()
# Out:
#    ï»¿Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0      40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1      26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2      25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3      13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4      47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.shape        
df.info()      
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿Row ID       1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   object
#  3   Ship Date       1000 non-null   object
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   Postal Code     194 non-null    float64
#  9   City            1000 non-null   object
#  10  State           1000 non-null   object
#  11  Country         1000 non-null   object
#  12  Region          1000 non-null   object
#  13  Market          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
# ...

# %%
df.isnull().sum()                    # see which columns have nulls

df["Sales"].fillna(df["Sales"].median(), inplace=True)   # numeric → median
df["City"].fillna("Unknown", inplace=True)               # text → Unknown
df.dropna(subset=["Order ID"])
# Out:
#      ï»¿Row ID                  Order ID  Order Date   Ship Date  \
# 0        40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014
# 1        26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014
# 2        25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3        13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4        47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014
# ..         ...                       ...         ...         ...
# 995      24278   IN-2015-JF1541527-42095    4/1/2015    4/5/2015
# 996      36249  CA-2015-AS10225140-42347   12/9/2015  12/13/2015
# 997      30517   IN-2014-CK1259592-41929  10/17/2014  10/19/2014
# 998       1408   MX-2014-SS2014018-41658   1/19/2014   1/26/2014
# 999      20944  ID-2015-RP19855130-42348  12/10/2015  12/14/2015
#
#           Ship Mode   Customer ID      Customer Name      Segment  \
# 0       First Class  AB-100151402      Aaron Bergman     Consumer
# ...

# %%
df.duplicated().sum()      
df.drop_duplicates(inplace=True)

# %%
print("Duplicates before:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
df["Ship Date"]  = pd.to_datetime(df["Ship Date"],  dayfirst=True)
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_8560\1127565402.py:1: UserWarning: Parsing '10/17/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
# C:\Users\faisa\AppData\Local\Temp\ipykernel_8560\1127565402.py:1: UserWarning: Parsing '12/26/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
# C:\Users\faisa\AppData\Local\Temp\ipykernel_8560\1127565402.py:1: UserWarning: Parsing '11/13/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], format="mixed", dayfirst=False)
df["Ship Date"]  = pd.to_datetime(df["Ship Date"],  format="mixed", dayfirst=False)

# %%
print(df[["Order Date", "Ship Date"]].dtypes)
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
df.to_csv("Global_Superstore_Cleaned.csv", index=False)
print("Done! File saved.")
# Out:
# Done! File saved.
